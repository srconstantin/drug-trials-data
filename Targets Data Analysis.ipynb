# %%
import pandas as pd

# %%
targetdata = pd.read_csv('target_results.csv')

# %%
targetdata
# Out:
#          NCT Number  Start Date  Approval Date  \
# 0       NCT02003625      2013.0         2000.0
# 1       NCT01801917      2013.0         2019.0
# 2       NCT02253940      2006.0         1996.0
# 3       NCT02253940      2006.0         1996.0
# 4       NCT05239468      2022.0         2016.0
# ...             ...         ...            ...
# 151582  NCT06249854      2024.0         2014.0
# 151583  NCT00921154      2005.0         1996.0
# 151584  NCT00796705      2008.0         2002.0
# 151585  NCT00796705      2008.0         1998.0
# 151586  NCT01663805      2012.0         2009.0
#
#                                               Target            Success
# 0                       Prostaglandin G/H synthase 2  Old Approved Drug
# 1                 Sphingosine 1-phosphate receptor 1            Success
# 2       Human immunodeficiency virus type 1 protease  Old Approved Drug
# 3                                 Cytochrome P450 3A  Old Approved Drug
# 4                                 Bile acid receptor  Old Approved Drug
# ...                                              ...                ...
# 151582               Programmed cell death protein 1  Old Approved Drug
# 151583              Glutamate-gated chloride channel  Old Approved Drug
# 151584                                     TNF-alpha  Old Approved Drug
# 151585                                     TNF-alpha  Old Approved Drug
# 151586                      FK506-binding protein 1A  Old Approved Drug
#
# [151587 rows x 5 columns]

# %%
oldapproved = targetdata[targetdata['Success'] == 'Old Approved Drug']

# %%
len(oldapproved) / len(targetdata)
# Out:
# 0.7595506210954766

# %%
success = targetdata[targetdata['Success'] == 'Success']

# %%
len(success)
# Out:
# 13566

# %%
failure = targetdata[targetdata['Success'] == 'No Success']

# %%
len(failure)
# Out:
# 20275

# %%
#fraction of studies on not-yet-approved drugs, with known targets, for which the drug was later approved

# %%
len(success)/(len(success) + len(failure))
# Out:
# 0.4008746786442481

# %%
targetdata['Target'].nunique()
# Out:
# 1519

# %%
targetdata['Target'].value_counts()
# Out:
# Target
# DNA                                          12603
# Glucocorticoid receptor                       4799
# Tubulin                                       4543
# Programmed cell death protein 1               3751
# RNA                                           3607
#                                              ...
# Ryanodine receptor 3                             1
# Carbepenem-hydrolyzing beta-lactamase KPC        1
# Glutamyl aminopeptidase                          1
# Alpha-1D adrenergic receptor                     1
# Alginate polysaccharide                          1
# Name: count, Length: 1519, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
targetdata['Target'].value_counts()[0:10]
# Out:
# Target
# DNA                                                          12603
# Glucocorticoid receptor                                       4799
# Tubulin                                                       4543
# Programmed cell death protein 1                               3751
# RNA                                                           3607
# Thymidylate synthase                                          2728
# GABA-A receptor; anion channel                                2605
# Cyclooxygenase                                                2377
# B-lymphocyte antigen CD20                                     1762
# Human immunodeficiency virus type 1 reverse transcriptase     1526
# Name: count, dtype: int64

# %%
success['Target'].value_counts()
# Out:
# Target
# Programmed cell death protein 1                365
# DNA                                            263
# Programmed cell death 1 ligand 1               249
# Vascular endothelial growth factor receptor    239
# Epidermal growth factor receptor erbB1         239
#                                               ...
# DNA topoisomerase II                             1
# Complement C1s                                   1
# Retinoid X receptor                              1
# Estrogen receptor beta                           1
# Ferriprotoporphyrin IX                           1
# Name: count, Length: 593, dtype: int64

# %%
success['Target'].value_counts()[0:10]
# Out:
# Target
# Programmed cell death protein 1                365
# DNA                                            263
# Programmed cell death 1 ligand 1               249
# Vascular endothelial growth factor receptor    239
# Epidermal growth factor receptor erbB1         239
# Glucagon-like peptide 1 receptor               204
# Sodium/glucose cotransporter 2                 195
# Stem cell growth factor receptor               194
# Tubulin                                        189
# FK506-binding protein 1A                       185
# Name: count, dtype: int64

# %%
targetdata[(targetdata['Start Date']==2025) & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()
# Out:
# Target
# Programmed cell death protein 1           110
# Serotonin 2a (5-HT2a) receptor             37
# Programmed cell death 1 ligand 1           23
# Epidermal growth factor receptor erbB1     15
# Tyrosine-protein kinase BTK                14
#                                          ...
# PI3-kinase p110-gamma subunit               1
# Tissue factor pathway inhibitor             1
# Transforming growth factor beta-2 mRNA      1
# Interleukin-8 receptors, CXCR1/CXCR2        1
# B-lymphocyte antigen CD19                   1
# Name: count, Length: 217, dtype: int64

# %%
#top 10 targets, 2020-2025

# %%
targetdata[(targetdata['Start Date']>=2020) & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()[0:10]
# Out:
# Target
# Programmed cell death protein 1                  1063
# Programmed cell death 1 ligand 1                  167
# Epidermal growth factor receptor erbB1            166
# Vascular endothelial growth factor receptor 2     144
# Cytotoxic T-lymphocyte protein 4                  123
# Serotonin 2a (5-HT2a) receptor                    121
# Tyrosine-protein kinase BTK                       114
# Vascular endothelial growth factor receptor 3     108
# T cell surface glycoprotein CD3                    98
# Stem cell growth factor receptor                   94
# Name: count, dtype: int64

# %%
#will ya look at all that cancer! especially PD1!!

# %%
#top 10 targets, 2015-2020

# %%
targetdata[(targetdata['Start Date']<2020) & (targetdata['Start Date']>=2015) & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()[0:10]
# Out:
# Target
# Programmed cell death protein 1                  295
# Programmed cell death 1 ligand 1                 254
# Epidermal growth factor receptor erbB1           133
# Tyrosine-protein kinase BTK                      106
# Cyclin-dependent kinase 4                         92
# Cyclin-dependent kinase 6                         92
# Tyrosine-protein kinase JAK1                      87
# Stem cell growth factor receptor                  84
# Cytotoxic T-lymphocyte protein 4                  81
# Vascular endothelial growth factor receptor 2     76
# Name: count, dtype: int64

# %%
#we still love cancer and IO, but not as insanely so

# %%
#top 10 targets, 2010-2015

# %%
targetdata[(targetdata['Start Date']<2015) & (targetdata['Start Date']>=2010) & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()[0:10]
# Out:
# Target
# Vascular endothelial growth factor receptor                   124
# Sodium/glucose cotransporter 2                                122
# Hepatitis C virus serine protease, NS3/NS4A                   121
# Epidermal growth factor receptor erbB1                        104
# Dual specificity mitogen-activated protein kinase kinase 1     90
# Dual specificity mitogen-activated protein kinase kinase 2     90
# Serine/threonine-protein kinase mTOR                           84
# Hepatocyte growth factor receptor                              83
# PI3-kinase class I                                             81
# Platelet-derived growth factor receptor                        79
# Name: count, dtype: int64

# %%
#o hai things that aren't cancer. diabetes! hep C!

# %%
# top 10 targets, 2005-2010

# %%
targetdata[(targetdata['Start Date']<2010) & (targetdata['Start Date']>=2005) & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()[0:10]
# Out:
# Target
# Vascular endothelial growth factor receptor     189
# FK506-binding protein 1A                        155
# Stem cell growth factor receptor                114
# Platelet-derived growth factor receptor         106
# Tubulin                                         103
# Tyrosine-protein kinase receptor RET             93
# DNA                                              92
# Tyrosine-protein kinase receptor FLT3            75
# Epidermal growth factor receptor                 74
# Platelet-derived growth factor receptor beta     68
# Name: count, dtype: int64

# %%
#top 10 targets, 2000-2005

# %%
targetdata[(targetdata['Start Date']<2005)  & (targetdata['Success'] != 'Old Approved Drug')]['Target'].value_counts()[0:10]
# Out:
# Target
# DNA                                             236
# Epidermal growth factor receptor erbB1          130
# Tubulin                                          90
# Stem cell growth factor receptor                 83
# Vascular endothelial growth factor receptor      63
# Platelet-derived growth factor receptor beta     57
# Thymidylate synthase                             54
# Cyclin-dependent kinase 4                        54
# Cyclin-dependent kinase 2                        54
# Cyclin-dependent kinase 6                        53
# Name: count, dtype: int64

# %%
#good old fashioned cytotoxic chemo!!

# %%
#define a target as ever-successful if *any* not-previously-approved drugs in studies were subsequently approved

# %%
eversuccessful = set(success['Target'])

# %%
len(eversuccessful)
# Out:
# 593

# %%
new = targetdata[(targetdata['Success'] == 'Success') | (targetdata['Success'] == 'No Success')]

# %%
newtargets = set(new['Target'])

# %%
len(newtargets)
# Out:
# 1360

# %%
targetsuccessrate = len(eversuccessful)/len(newtargets)

# %%
targetsuccessrate
# Out:
# 0.4360294117647059

# %%
neversuccessful = set([x for x in list(newtargets) if x not in list(eversuccessful)])

# %%
len(neversuccessful)
# Out:
# 767

# %%
# most popular never successful targets

# %%
targetdata[targetdata['Target'].isin(neversuccessful)]['Target'].value_counts()[0:20]
# Out:
# Target
# Glycine receptor (alpha-1/beta)             484
# Oxytocin receptor                           459
# Anandamide amidohydrolase                   403
# Inosine-5'-monophosphate dehydrogenase 1    376
# Sulfonylurea receptor 1, Kir6.2             335
# Cyclophilin A                               305
# Vitamin D3 receptor                         208
# 5-hydroxytryptamine receptor 2C             194
# Prostanoid EP3 receptor                     190
# Peptidoglycan                               189
# Serine/threonine-protein kinase mTOR        185
# DNA topoisomerase 2-alpha                   178
# Fatty-acid amide hydrolase 1                171
# Sodium/potassium-transporting ATPase        152
# Histamine H2 receptor                       151
# Matrix metalloproteinase 13                 150
# Matrix metalloproteinase-1                  149
# Matrix metalloproteinase 8                  149
# Phosphodiesterase 3                         147
# Glucagon receptor                           147
# Name: count, dtype: int64

# %%
#lololol it's never vitamin D. 
#and pain is hard (FAAH/anandamide, Substance P, prostaglandins)
#some chemo targets have been unsuccessful
#sulfonylureas aren't great (for diabetes)

# %%
targetdata[targetdata['Target'].isin(eversuccessful)]['Target'].value_counts()[0:20]
# Out:
# Target
# DNA                                                          12603
# Glucocorticoid receptor                                       4799
# Tubulin                                                       4543
# Programmed cell death protein 1                               3751
# RNA                                                           3607
# Thymidylate synthase                                          2728
# GABA-A receptor; anion channel                                2605
# Cyclooxygenase                                                2377
# B-lymphocyte antigen CD20                                     1762
# Human immunodeficiency virus type 1 reverse transcriptase     1526
# Epidermal growth factor receptor erbB1                        1456
# DNA polymerase (alpha/delta/epsilon)                          1380
# Vascular endothelial growth factor A                          1356
# Programmed cell death 1 ligand 1                              1336
# Insulin receptor                                              1275
# Sodium channel alpha subunit                                  1271
# CRL4(CRBN) E3 ubiquitin ligase                                1240
# Stem cell growth factor receptor                              1176
# Serotonin 2a (5-HT2a) receptor                                1099
# Glucagon-like peptide 1 receptor                              1036
# Name: count, dtype: int64

# %%
#chemo!
