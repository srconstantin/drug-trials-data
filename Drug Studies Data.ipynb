# %%
import pandas as pd
from matplotlib import *

# %%
drug_studies = pd.read_csv('drug_studies.csv')

# %%
drug_studies.head()
# Out:
#    Unnamed: 0   NCT Number                                        Study Title  \
# 0           0  NCT02003625              Meloxicam vs Placebo for Mobilization
# 1           3  NCT02382276  A Long-term Extension Study for the Phase 3 St...
# 2           4  NCT03782376  A Study to Evaluate Efficacy and Safety of Ust...
# 3           6  NCT01801917  Efficacy and Tolerability of BAF312 in Patient...
# 4          12  NCT02253940  Pharmacokinetics and Safety of BILR 355 in Hea...
#
#                                       Study URL Study Status  \
# 0  https://clinicaltrials.gov/study/NCT02003625    COMPLETED
# 1  https://clinicaltrials.gov/study/NCT02382276    COMPLETED
# 2  https://clinicaltrials.gov/study/NCT03782376    COMPLETED
# 3  https://clinicaltrials.gov/study/NCT01801917   TERMINATED
# 4  https://clinicaltrials.gov/study/NCT02253940    COMPLETED
#
#                                        Brief Summary Study Results  \
# ...

# %%
drug_studies['Phases'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Phases'>

# %%
pd.to_datetime(drug_studies['Completion Date'], format='mixed').hist(bins=100)
# Out:
# <Axes: >

# %%
pd.to_datetime(drug_studies['Start Date'], format='mixed').hist(bins=100)
# Out:
# <Axes: >

# %%
pd.to_datetime(drug_studies['Start Date'], format='mixed').min()
# Out:
# Timestamp('1900-01-01 00:00:00')

# %%
pd.to_datetime(drug_studies['Completion Date'], format='mixed').min()
# Out:
# Timestamp('1900-01-01 00:00:00')
